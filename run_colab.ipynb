# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeMesh39/Smartflow-Traffic/blob/main/run_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install -y sumo sumo-tools sumo-doc
# !pip install traci
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,640 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,879 kB]
# ...

# %%
# !rm -rf Smartflow-Traffic
# !git clone https://github.com/CodeMesh39/Smartflow-Traffic.git
# %cd Smartflow-Traffic
# Out:
# Cloning into 'Smartflow-Traffic'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 35 (delta 8), reused 21 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 13.66 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/Smartflow-Traffic/Smartflow-Traffic

# %%
pip install -r requirements.txt

# %%
# !python3 train.py
# Out:
#  Retrying in 1 seconds
# ...
# Episode 0 | Total Reward: -1476.80
# Episode 1 | Total Reward: -1472.40
# Episode 2 | Total Reward: -1185.20
# Episode 3 | Total Reward: -2002.40
# Episode 4 | Total Reward: -2692.00
# Step #1100.00 (1ms ~= 1Episode 5 | Total Reward: -1348.80
# Episode 6 | Total Reward: -986.40
# Episode 7 | Total Reward: -2308.00
# Episode 8 | Total Reward: -1493.20
# Episode 9 | Total Reward: -1040.80
# Episode 10 | Total Reward: -1727.60
# Step #2200.00 (1ms ~= 1000.00*RT, ~45000.00UPSEpisode 11 | Total Reward: -2116.40
# Episode 12 | Total Reward: -977.20
# Episode 13 | Total Reward: -2105.60
# Episode 14 | Total Reward: -1557.20
# Episode 15 | Total Reward: -1089.20
# Step #3300.00 (1ms ~= 1000.00*RT, ~47000.00UPS, TraCI: 4ms, vehicles Episode 16 | Total Reward: -881.60
# Episode 17 | Total Reward: -1313.20
# Episode 18 | Total Reward: -1500.80
# Episode 19 | Total Reward: -2187.20
# Episode 20 | Total Reward: -1428.00
# Episode 21 | Total Reward: -1013.20
# ...

# %%
# !python3 test.py
# Out:
#  Retrying in 1 seconds
# ...
# Step #10001.00 (2ms ~= 500.00*RT, ~23000.00UPS, TraCI: 2ms, vehicles TOT 5807 ACT 46 BUF 4
# Test completed!

# %%
# !git add .
# !git commit -m "Update files"
# !git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@357907386aef.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address
